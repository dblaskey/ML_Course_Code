# %% [markdown]
# # Lecture 2 In-class Activity

# %%
library(tidyverse)
library(lubridate)

# %% [markdown]
# ## Warm up

# %% [markdown]
# Given the list below:

# %%
quiz_scores <- c(78, 85, 92, 67, 88, 95, 73, 84)

# %% [markdown]
# Write code to:
# 1. Print the first score.
# 2. Print the last score.
# 3. Calculate the average score.
# 4. Create a new list containing only scores greater than or equal to 80.
# 5. Count how many students scored below 80.

# %% [markdown]
# Write a function called letter_grade that takes a numeric score and returns:
# | Score Range | Grade |
# | ----------- | ----- |
# | 90 or above | A     |
# | 80–89       | B     |
# | 70–79       | C     |
# | 60–69       | D     |
# | Below 60    | F     |

# %% [markdown]
# Example:
# ```R
# letter_grade(92)
# ```
# Expected output:
# ```R
# A
# ```

# %% [markdown]
# Then:
# 7. Create a dataframe using the list quiz score.
# 8. Create a new column named Letter_Grade by applying the letter_grade function.

# %% [markdown]
# Add the following list as a column named HoursOfStudy:

# %%
study_hours <- c("1", "1.5", "2.5", "0", "1", "1.5", "0.5", "1")

# %% [markdown]
# Once you create the column, do the following:
# 9. Change the column to numeric.
# 10. Create a plot with HoursOfStudy and quiz_scores.
# 11. Make the plot look pretty.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# For this part, we will be working with an actual dataset.
#
# Load the following dataset https://raw.githubusercontent.com/dblaskey/ML_Course_Code/main/Data/weatherHistory.csv

# %% [markdown]
# It is usually best practice to keep a raw copy of the original data (unless the dataset is exceptionally large). Create a copy of the dataset.

# %% [markdown]
# Clean the column names of the dataframe by:
# 1. Remove spaces at the beginning and end of the column name
# 2. Convert all column names to lowercase.
# 3. Replaces any group of characters that is not a letter or number with an underscore.
# 4. Remove underscores from the beginning and end.

# %% [markdown]
# Now that you have cleaned column names, it is time to understand and clean the dataset:
# 1. Notice there seems to be a typo in the column heading. Change Loud Cover to Cloud Cover.
# 2. Check for impossible data such as precip, wind speed, visibility, cloud cover, or pressure < 0 and any variable outside of earthly max and min values.
# 3. Give the count, mean, standard deviation, max, and min values of each of the columns.
# 4. Count the number of missing values for each column.
# 5. Create a new column changing Formatted Date to a datetime column.
# 6. Create new columns for hour, day, month, and year.

# %% [markdown]
# Now we will create multiple plots to continue to explore the dataset.
# 1. Plot a timeseries plot of windspeed.
# 2. Create a second timeseries plot of air temperature and humidity using two different axes.
# 3. Plot a daily average temperature (i.e. average all the January 1st, the January 2nds, and so on).
# 4. Make the plots look pretty.
